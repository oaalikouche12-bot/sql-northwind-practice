# %% [markdown]
# <a href="https://colab.research.google.com/github/oaalikouche12-bot/sql-northwind-practice/blob/main/Copia_de_UPF_MUDAB_2025_Caso_Pr%C3%A1ctico_1_SQL_OMAR_AALIKOUCHE_ALICHANE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparar el entorno

# %% [markdown]
# ## Instalación de PostgreSQL e importación de librerías

# %% [markdown]
# ### Creación del servidor PostgreSQL
# El siguiente código levanta un PostgreSQL en la máquina del google COLAB y lo inicializa, tanto el usuario como la contraseña para acceder a la base de datos se pueden cambiar pero por defecto serán "postgres" ambas.
#
# El siguiente código también genera una base de datos llamada "northwind" que será la que usaremos.
#
# `psql` es el comando del servicio de postgresql, es el que usamos para mandarle comandos a la hora de editar el usuario y crear la base de datos.

# %%
# Importo librería para ejecutar comandos de shell
import subprocess

# Instalamos postgresql server en la máquina del COLAB
# !sudo apt-get -y -qq update
# !sudo apt-get -y -qq install postgresql
# !sudo service postgresql start

# Ejecutar el comando para verificar el estado del servicio PostgreSQL
result = subprocess.run(['service', 'postgresql', 'status'], stdout=subprocess.PIPE)
STATUS_OUTPUT = result.stdout.decode('utf-8')
print(STATUS_OUTPUT)

# Verificar si la palabra "online" está presente en la salida del comando y que muestre online.
if "online" in STATUS_OUTPUT:
    print("PostgreSQL se encuentra online :). Se ha levantado la BBDD.")
else:
    print("PostgreSQL no se encuentra online")

# Variables para la configuración (nombre base de datos, usuario, puerto, ...)
SQL_PRACTICE_DATABASE_NAME="northwind"
SQL_PRACTICE_DATABASE_HOST="localhost"
SQL_PRACTICE_DATABASE_PORT=5432
SQL_PRACTICE_DATABASE_USER="postgres"
SQL_PRACTICE_DATABASE_PASS="postgres"

# Dropeamos BBDD porque no le gusta matar sesiones. (Daba error al ejecutar el Collab porque había otra sesión) + Cambio del password para el username `postgres`
# !sudo -u postgres psql -U postgres -c "DROP DATABASE {SQL_PRACTICE_DATABASE_NAME} WITH (FORCE);"
# !sudo -u postgres psql -U postgres -c "ALTER USER postgres PASSWORD '{SQL_PRACTICE_DATABASE_PASS}';"

# Creación de la base de datos
# !sudo -u postgres psql -U postgres -c "DROP DATABASE IF EXISTS {SQL_PRACTICE_DATABASE_NAME};"
# !sudo -u postgres psql -U postgres -c "CREATE DATABASE {SQL_PRACTICE_DATABASE_NAME};"
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#  * Starting PostgreSQL 14 database server
#    ...done.
# 14/main (port 5432): online
#
# PostgreSQL se encuentra online :). Se ha levantado la BBDD.
# DROP DATABASE
# ALTER ROLE
# NOTICE:  database "northwind" does not exist, skipping
# DROP DATABASE
# CREATE DATABASE

# %% [markdown]
# ### Importamos las librerías necesarias
# - **[psycopg2](https://www.psycopg.org/)**. Librería que nos permite interactuar con servidores y clientes de postgresql
# - **pandas**. Librearía conocida para el análisis y transformación de datos.

# %%
import psycopg2
import pandas as pd

# %% [markdown]
# ## Creación de tablas y carga de datos en el servidor PostgreSQL
#
# Como hemos visto, la [base de datos de Northwind](https://dbdocs.io/akweiwonder3/Northwind-Database?schema=public&view=relationships&table=order_details) tiene varias tablas, el objetivo de esta práctica es familiarizarse con los comandos de consulta de SQL y no de creación de base de datos, por lo que usaremos un script que nos creará todas las tablas y nos cargará todos los datos.

# %% [markdown]
# ### Creación y configuración base de datos

# %%
# Primero creamos la conexión usando la librearía psycopg2
# https://pypi.org/project/psycopg2/
connection = psycopg2.connect(host=SQL_PRACTICE_DATABASE_HOST,
                              database=SQL_PRACTICE_DATABASE_NAME,
                              user=SQL_PRACTICE_DATABASE_USER,
                              password=SQL_PRACTICE_DATABASE_PASS)
connection.set_isolation_level(psycopg2.extensions.ISOLATION_LEVEL_AUTOCOMMIT);

# Creamos el cursor en la conexión, el cursor es nuestra "puerta de acceso" a la base de datos usando
# la conexión configurada
cursor = connection.cursor()

# %%
# Creación de tablas
# %env SQL_PRACTICE_DATABASE_NAME = SQL_PRACTICE_DATABASE_NAME
# %env SQL_PRACTICE_DATABASE_HOST = SQL_PRACTICE_DATABASE_HOST
# %env SQL_PRACTICE_DATABASE_PORT = SQL_PRACTICE_DATABASE_PORT
# %env SQL_PRACTICE_DATABASE_USER = SQL_PRACTICE_DATABASE_USER
# %env SQL_PRACTICE_DATABASE_PASS = SQL_PRACTICE_DATABASE_PASS

# !PGPASSWORD=$SQL_PRACTICE_DATABASE_PASS psql -q -h $SQL_PRACTICE_DATABASE_HOST -p $SQL_PRACTICE_DATABASE_PORT -U $SQL_PRACTICE_DATABASE_USER -d $SQL_PRACTICE_DATABASE_NAME -f northwind_ddl_full.sql

# !PGPASSWORD=$SQL_PRACTICE_DATABASE_PASS psql -q -h $SQL_PRACTICE_DATABASE_HOST -p $SQL_PRACTICE_DATABASE_PORT -U $SQL_PRACTICE_DATABASE_USER -d $SQL_PRACTICE_DATABASE_NAME -f northwind_data.sql
# Out:
# env: SQL_PRACTICE_DATABASE_NAME=SQL_PRACTICE_DATABASE_NAME
# env: SQL_PRACTICE_DATABASE_HOST=SQL_PRACTICE_DATABASE_HOST
# env: SQL_PRACTICE_DATABASE_PORT=SQL_PRACTICE_DATABASE_PORT
# env: SQL_PRACTICE_DATABASE_USER=SQL_PRACTICE_DATABASE_USER
# env: SQL_PRACTICE_DATABASE_PASS=SQL_PRACTICE_DATABASE_PASS

# %% [markdown]
# # Ejercicios

# %%
# Método de pandas para lanzar consultas SQL y cargarlas en un dataframe
pd.read_sql("select * from categories", connection)
# Out:
# /tmp/ipython-input-96391461.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from categories", connection)
#    category_id   category_name  \
# 0            1       Beverages
# 1            2      Condiments
# 2            3     Confections
# 3            4  Dairy Products
# 4            5  Grains/Cereals
# 5            6    Meat/Poultry
# 6            7         Produce
# 7            8         Seafood
#
#                                          description picture
# 0        Soft drinks, coffees, teas, beers, and ales      []
# 1  Sweet and savory sauces, relishes, spreads, an...      []
# 2                Desserts, candies, and sweet breads      []
# 3                                            Cheeses      []
# 4                Breads, crackers, pasta, and cereal      []
# 5                                     Prepared meats      []
# 6                          Dried fruit and bean curd      []
# 7                                   Seaweed and fish      []

# %%
# En lugar de usar cursor.execute(sql) y cursor.fetchall() para mostrar resultados
# mejor usar la función read_sql de Pandas que nos devuelve directamente un dataframe

# Creamos una función más simple para no tener que escribir todo cada vez que lancemos una query
def query(sql):
  return pd.read_sql(sql, connection)

# %% [markdown]
# ## 1. Informe completo de todos los pedidos (orders) desde el origen de los tiempos
# Es decir, sacar todos los Orders tal cual, con toda la información

# %%
query("""select * from orders""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#      order_id customer_id  employee_id  order_date required_date shipped_date  \
# 0       10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 1       10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
# 2       10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12
# 3       10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15
# 4       10252       SUPRD            4  1996-07-09    1996-08-06   1996-07-11
# ..        ...         ...          ...         ...           ...          ...
# 825     11073       PERIC            2  1998-05-05    1998-06-02         None
# 826     11074       SIMOB            7  1998-05-06    1998-06-03         None
# 827     11075       RICSU            8  1998-05-06    1998-06-03         None
# 828     11076       BONAP            4  1998-05-06    1998-06-03         None
# 829     11077       RATTC            1  1998-05-06    1998-06-03         None
#
#      ship_via  freight                   ship_name              ship_address  \
# 0           3    32.38   Vins et alcools Chevalier        59 rue de l'Abbaye
# 1           1    11.61          Toms Spezialitäten             Luisenstr. 48
# 2           2    65.83               Hanari Carnes           Rua do Paço, 67
# 3           1    41.34        Victuailles en stock        2, rue du Commerce
# 4           2    51.30            Suprêmes délices      Boulevard Tirou, 255
# ..        ...      ...                         ...                       ...
# 825         2    24.95   Pericles Comidas clásicas  Calle Dr. Jorge Cash 321
# 826         2    18.44               Simons bistro              Vinbæltet 34
# 827         2     6.19          Richter Supermarkt               Starenweg 5
# 828         2    38.28                    Bon app'      12, rue des Bouchers
# 829         2     8.53  Rattlesnake Canyon Grocery           2817 Milton Dr.
#
#           ship_city ship_region ship_postal_code ship_country
# 0             Reims        None            51100       France
# 1           Münster        None            44087      Germany
# 2    Rio de Janeiro          RJ        05454-876       Brazil
# 3              Lyon        None            69004       France
# 4         Charleroi        None           B-6000      Belgium
# ..              ...         ...              ...          ...
# 825     México D.F.        None            05033       Mexico
# 826       Kobenhavn        None             1734      Denmark
# 827          Genève        None             1204  Switzerland
# 828       Marseille        None            13008       France
# 829     Albuquerque          NM            87110          USA
#
# [830 rows x 14 columns]

# %% [markdown]
# ## 2. Se necesitan dos reports sobre los Customers:
# - Lista de Customers/Contacts que son managers
# - Lista de Customer/Contacts que no son managers
#
# Ambos reportes tendrán que estar ordenados alfabéticamente por país y nombre para cargarlos en el CRM (formato específico), además las columnas tienen que tener los siguientes nombres para evitar problemas en la carga: compañia, nombre, posicion, direccion, ciudad, pais.
#
# _Funciones útiles: [SQL Like](https://www.w3schools.com/sql/sql_like.asp), [SQL IN](https://www.w3schools.com/sql/sql_in.asp), [SQL Aliases](https://www.w3schools.com/sql/sql_alias.asp), [DISTINCT](https://www.w3schools.com/sql/sql_distinct.asp)_

# %%
query("""select company_name as Compañia, contact_name as nombre, contact_title as posicion, address as direccion, city as ciudad, country as pais
 from customers where contact_title like '%Manager' order by country, contact_name""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#                                 compañia              nombre  \
# 0                       Piccolo und mehr         Georg Pipps
# 1                           Ernst Handel       Roland Mendel
# 2                       Suprêmes délices    Pascale Cartrain
# 3                            Que Delícia    Bernardo Batista
# 4                          Hanari Carnes        Mario Pontes
# 5                 Wellington Importadora       Paula Parente
# 6                  Bottom-Dollar Markets   Elizabeth Lincoln
# 7                           Vaffeljernet         Palle Ibsen
# 8                         Wartian Herkku    Pirkko Koskitalo
# 9                       La maison d'Asie      Annette Roulet
# 10                   France restauration      Carine Schmitt
# 11                  Spécialités du monde   Dominique Perrier
# 12              Blondesddsl père et fils  Frédérique Citeaux
# 13             Vins et alcools Chevalier        Paul Henriot
# 14                            QUICK-Stop         Horst Kloss
# 15                    Toms Spezialitäten       Karin Josephs
# 16                        Frankenversand       Peter Franken
# 17          Magazzini Alimentari Riuniti    Giovanni Rovelli
# 18            Centro comercial Moctezuma     Francisco Chang
# 19        Furia Bacalhau e Frutos do Mar      Lino Rodriguez
# 20                      Romero y tomillo    Alejandra Camino
# 21  FISSA Fabrica Inter. Salchichas S.A.          Diego Roel
# 22                Galería del gastrónomo    Eduardo Saavedra
# 23                   Godos Cocina Típica   José Pedro Freyre
# 24                    Richter Supermarkt        Michael Holz
# 25                    Seven Seas Imports          Hari Kumar
# 26                        Island Trading       Helen Bennett
# 27                 Split Rail Beer & Ale  Art Braunschweiger
# 28              Lonesome Pine Restaurant         Fran Wilson
# 29               Great Lakes Food Market       Howard Snyder
# 30                  Lazy K Kountry Store          John Steel
# 31                        The Big Cheese           Liz Nixon
# 32                     LILA-Supermercado     Carlos González
#
#               posicion                                       direccion  \
# 0        Sales Manager                                     Geislweg 14
# 1        Sales Manager                                    Kirchgasse 6
# 2   Accounting Manager                            Boulevard Tirou, 255
# 3   Accounting Manager                         Rua da Panificadora, 12
# 4   Accounting Manager                                 Rua do Paço, 67
# 5        Sales Manager                              Rua do Mercado, 12
# 6   Accounting Manager                              23 Tsawassen Blvd.
# 7        Sales Manager                                   Smagsloget 45
# 8   Accounting Manager                                     Torikatu 38
# 9        Sales Manager                           1 rue Alsace-Lorraine
# 10   Marketing Manager                                  54, rue Royale
# 11   Marketing Manager                               25, rue Lauriston
# 12   Marketing Manager                                24, place Kléber
# 13  Accounting Manager                              59 rue de l'Abbaye
# 14  Accounting Manager                                Taucherstraße 10
# 15   Marketing Manager                                   Luisenstr. 48
# 16   Marketing Manager                               Berliner Platz 43
# 17   Marketing Manager                         Via Ludovico il Moro 22
# 18   Marketing Manager                         Sierras de Granada 9993
# 19       Sales Manager                          Jardim das rosas n. 32
# 20  Accounting Manager                                     Gran Vía, 1
# 21  Accounting Manager                              C/ Moralzarzal, 86
# 22   Marketing Manager                          Rambla de Cataluña, 23
# 23       Sales Manager                                   C/ Romero, 33
# 24       Sales Manager                               Grenzacherweg 237
# 25       Sales Manager                                 90 Wadhurst Rd.
# 26   Marketing Manager                       Garden House Crowther Way
# 27       Sales Manager                                    P.O. Box 555
# 28       Sales Manager                              89 Chiaroscuro Rd.
# 29   Marketing Manager                                2732 Baker Blvd.
# 30   Marketing Manager                            12 Orchestra Terrace
# 31   Marketing Manager                        89 Jefferson Way Suite 2
# 32  Accounting Manager  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
#
#             ciudad         pais
# 0         Salzburg      Austria
# 1             Graz      Austria
# 2        Charleroi      Belgium
# 3   Rio de Janeiro       Brazil
# 4   Rio de Janeiro       Brazil
# 5          Resende       Brazil
# 6        Tsawassen       Canada
# 7            Århus      Denmark
# 8             Oulu      Finland
# 9         Toulouse       France
# 10          Nantes       France
# 11           Paris       France
# 12      Strasbourg       France
# 13           Reims       France
# 14       Cunewalde      Germany
# 15         Münster      Germany
# 16         München      Germany
# 17         Bergamo        Italy
# 18     México D.F.       Mexico
# 19          Lisboa     Portugal
# 20          Madrid        Spain
# 21          Madrid        Spain
# 22       Barcelona        Spain
# 23         Sevilla        Spain
# 24          Genève  Switzerland
# 25          London           UK
# 26           Cowes           UK
# 27          Lander          USA
# 28        Portland          USA
# 29          Eugene          USA
# 30     Walla Walla          USA
# 31        Portland          USA
# 32    Barquisimeto    Venezuela

# %%
query("""select company_name as Compañia, contact_name as nombre, contact_title as posicion, address as direccion, city as ciudad, country as pais
 from customers where contact_title not like '%Manager' order by country, contact_name""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#                               compañia                   nombre  \
# 0           Cactus Comidas para llevar         Patricio Simpson
# 1                        Rancho grande         Sergio Gutiérrez
# 2               Océano Atlántico Ltda.           Yvonne Moncada
# 3                         Maison Dewey          Catherine Dewey
# 4               Tradição Hipermercados        Anabela Domingues
# 5                  Gourmet Lanchonetes            André Fonseca
# 6                   Familia Arquibaldo                Aria Cruz
# 7                   Ricardo Adocicados           Janete Limeira
# 8                        Queen Cozinha           Lúcia Carvalho
# 9                     Comércio Mineiro             Pedro Afonso
# 10                      Mère Paillarde           Jean Fresnière
# 11       Laughing Bacchus Wine Cellars          Yoshi Tannamuri
# 12                       Simons bistro           Jytte Petersen
# 13                         Wilman Kala          Matti Karttunen
# 14                La corne d'abondance            Daniel Tonini
# 15                     Du monde entier           Janine Labrune
# 16                            Bon app'         Laurence Lebihan
# 17                   Paris spécialités           Marie Bertrand
# 18                   Folies gourmandes            Martine Rancé
# 19                Victuailles en stock             Mary Saveley
# 20              Morgenstern Gesundkost          Alexander Feuer
# 21             Blauer See Delikatessen               Hanna Moos
# 22                  Ottilies Käseladen      Henriette Pfalzheim
# 23                 Alfreds Futterkiste             Maria Anders
# 24                     Königlich Essen            Philip Cramer
# 25                 Lehmanns Marktstand           Renate Messner
# 26                   Die Wandernde Kuh              Rita Müller
# 27            Drachenblut Delikatessen             Sven Ottlieb
# 28        Hungry Owl All-Night Grocers         Patricia McKenna
# 29                  Reggiani Caseifici          Maurizio Moroni
# 30                      Franchi S.p.A.            Paolo Accorti
# 31  Ana Trujillo Emparedados y helados             Ana Trujillo
# 32             Antonio Moreno Taquería           Antonio Moreno
# 33           Pericles Comidas clásicas      Guillermo Fernández
# 34                 Tortuga Restaurante     Miguel Angel Paolino
# 35                       Santé Gourmet         Jonas Bergulfsen
# 36                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 37              Princesa Isabel Vinhos         Isabel de Castro
# 38           Bólido Comidas preparadas            Martín Sommer
# 39                  Berglunds snabbköp       Christina Berglund
# 40                      Folk och fä HB            Maria Larsson
# 41                   Chop-suey Chinese                Yang Wang
# 42                  Eastern Connection                Ann Devon
# 43               Consolidated Holdings          Elizabeth Brown
# 44                         North/South           Simon Crowther
# 45                     Around the Horn             Thomas Hardy
# 46                       B's Beverages        Victoria Ashworth
# 47   Trail's Head Gourmet Provisioners           Helvetius Nagy
# 48                   Let's Stop N Shop             Jaime Yorres
# 49                  Save-a-lot Markets           Jose Pavarotti
# 50                White Clover Markets           Karl Jablonski
# 51                     The Cracker Box                 Liu Wong
# 52          Rattlesnake Canyon Grocery             Paula Wilson
# 53              Old World Delicatessen            Rene Phillips
# 54          Hungry Coyote Import Store            Yoshi Latimer
# 55                    HILARION-Abastos         Carlos Hernández
# 56                    LINO-Delicateses         Felipe Izquierdo
# 57                GROSELLA-Restaurante           Manuel Pereira
#
#                           posicion  \
# 0                      Sales Agent
# 1             Sales Representative
# 2                      Sales Agent
# 3                      Sales Agent
# 4             Sales Representative
# 5                  Sales Associate
# 6              Marketing Assistant
# 7            Assistant Sales Agent
# 8              Marketing Assistant
# 9                  Sales Associate
# 10             Marketing Assistant
# 11             Marketing Assistant
# 12                           Owner
# 13       Owner/Marketing Assistant
# 14            Sales Representative
# 15                           Owner
# 16                           Owner
# 17                           Owner
# 18           Assistant Sales Agent
# 19                     Sales Agent
# 20             Marketing Assistant
# 21            Sales Representative
# 22                           Owner
# 23            Sales Representative
# 24                 Sales Associate
# 25            Sales Representative
# 26            Sales Representative
# 27             Order Administrator
# 28                 Sales Associate
# 29                 Sales Associate
# 30            Sales Representative
# 31                           Owner
# 32                           Owner
# 33            Sales Representative
# 34                           Owner
# 35                           Owner
# 36                           Owner
# 37            Sales Representative
# 38                           Owner
# 39             Order Administrator
# 40                           Owner
# 41                           Owner
# 42                     Sales Agent
# 43            Sales Representative
# 44                 Sales Associate
# 45            Sales Representative
# 46            Sales Representative
# 47                 Sales Associate
# 48                           Owner
# 49            Sales Representative
# 50                           Owner
# 51             Marketing Assistant
# 52  Assistant Sales Representative
# 53            Sales Representative
# 54            Sales Representative
# 55            Sales Representative
# 56                           Owner
# 57                           Owner
#
#                                      direccion           ciudad         pais
# 0                                  Cerrito 333     Buenos Aires    Argentina
# 1                       Av. del Libertador 900     Buenos Aires    Argentina
# 2          Ing. Gustavo Moncada 8585 Piso 20-A     Buenos Aires    Argentina
# 3                          Rue Joseph-Bens 532        Bruxelles      Belgium
# 4                      Av. Inês de Castro, 414        Sao Paulo       Brazil
# 5                              Av. Brasil, 442         Campinas       Brazil
# 6                                 Rua Orós, 92        Sao Paulo       Brazil
# 7                          Av. Copacabana, 267   Rio de Janeiro       Brazil
# 8                    Alameda dos Canàrios, 891        Sao Paulo       Brazil
# 9                         Av. dos Lusíadas, 23        Sao Paulo       Brazil
# 10                          43 rue St. Laurent         Montréal       Canada
# 11                                1900 Oak St.        Vancouver       Canada
# 12                                Vinbæltet 34        Kobenhavn      Denmark
# 13                               Keskuskatu 45         Helsinki      Finland
# 14                      67, avenue de l'Europe       Versailles       France
# 15                67, rue des Cinquante Otages           Nantes       France
# 16                        12, rue des Bouchers        Marseille       France
# 17                     265, boulevard Charonne            Paris       France
# 18                    184, chaussée de Tournai            Lille       France
# 19                          2, rue du Commerce             Lyon       France
# 20                                 Heerstr. 22          Leipzig      Germany
# 21                              Forsterstr. 57         Mannheim      Germany
# 22                          Mehrheimerstr. 369             Köln      Germany
# 23                               Obere Str. 57           Berlin      Germany
# 24                               Maubelstr. 90      Brandenburg      Germany
# 25                                Magazinweg 7   Frankfurt a.M.      Germany
# 26                           Adenauerallee 900        Stuttgart      Germany
# 27                                Walserweg 21           Aachen      Germany
# 28                            8 Johnstown Road             Cork      Ireland
# 29                      Strada Provinciale 124    Reggio Emilia        Italy
# 30                         Via Monte Bianco 34           Torino        Italy
# 31               Avda. de la Constitución 2222      México D.F.       Mexico
# 32                             Mataderos  2312      México D.F.       Mexico
# 33                    Calle Dr. Jorge Cash 321      México D.F.       Mexico
# 34                            Avda. Azteca 123      México D.F.       Mexico
# 35                      Erling Skakkes gate 78          Stavern       Norway
# 36                             ul. Filtrowa 68         Warszawa       Poland
# 37                      Estrada da saúde n. 58           Lisboa     Portugal
# 38                              C/ Araquil, 67           Madrid        Spain
# 39                             Berguvsvägen  8            Luleå       Sweden
# 40                                Åkergatan 24           Bräcke       Sweden
# 41                                Hauptstr. 29             Bern  Switzerland
# 42                              35 King George           London           UK
# 43                Berkeley Gardens 12  Brewery           London           UK
# 44                South House 300 Queensbridge           London           UK
# 45                             120 Hanover Sq.           London           UK
# 46                           Fauntleroy Circus           London           UK
# 47                           722 DaVinci Blvd.         Kirkland          USA
# 48                         87 Polk St. Suite 5    San Francisco          USA
# 49                             187 Suffolk Ln.            Boise          USA
# 50                 305 - 14th Ave. S. Suite 3B          Seattle          USA
# 51                         55 Grizzly Peak Rd.            Butte          USA
# 52                             2817 Milton Dr.      Albuquerque          USA
# 53                             2743 Bering St.        Anchorage          USA
# 54              City Center Plaza 516 Main St.            Elgin          USA
# 55  Carrera 22 con Ave. Carlos Soublette #8-35    San Cristóbal    Venezuela
# 56                     Ave. 5 de Mayo Porlamar  I. de Margarita    Venezuela
# 57                   5ª Ave. Los Palos Grandes          Caracas    Venezuela

# %% [markdown]
# ## 3. Se necesitan 4 reportes distintos:
# 1. Lista de Orders de 1996
# 2. Lista de Employees, con su nombre completo en un único campo, su edad y país
# 3. Número de Orders hechos desde el 15 de Julio de 1997
# 4. Media de días que se tarda en enviar un pedido desde que se hace
#
# _Funciones útiles: [CONCAT](https://www.postgresqltutorial.com/postgresql-string-functions/postgresql-concat-function/), [DATE_PART](https://www.postgresql.org/docs/8.1/functions-datetime.html), [COUNT](https://www.w3schools.com/sql/sql_count.asp), [AVG](https://www.w3schools.com/sql/sql_avg.asp)_

# %%
query("""select * from orders where order_date between '1996-01-01' and '1996-12-31'""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#      order_id customer_id  employee_id  order_date required_date shipped_date  \
# 0       10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 1       10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
# 2       10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12
# 3       10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15
# 4       10252       SUPRD            4  1996-07-09    1996-08-06   1996-07-11
# ..        ...         ...          ...         ...           ...          ...
# 147     10395       HILAA            6  1996-12-26    1997-01-23   1997-01-03
# 148     10396       FRANK            1  1996-12-27    1997-01-10   1997-01-06
# 149     10397       PRINI            5  1996-12-27    1997-01-24   1997-01-02
# 150     10398       SAVEA            2  1996-12-30    1997-01-27   1997-01-09
# 151     10399       VAFFE            8  1996-12-31    1997-01-14   1997-01-08
#
#      ship_via  freight                  ship_name  \
# 0           3    32.38  Vins et alcools Chevalier
# 1           1    11.61         Toms Spezialitäten
# 2           2    65.83              Hanari Carnes
# 3           1    41.34       Victuailles en stock
# 4           2    51.30           Suprêmes délices
# ..        ...      ...                        ...
# 147         1   184.41           HILARION-Abastos
# 148         3   135.35             Frankenversand
# 149         1    60.26     Princesa Isabel Vinhos
# 150         3    89.16         Save-a-lot Markets
# 151         3    27.36               Vaffeljernet
#
#                                    ship_address       ship_city ship_region  \
# 0                            59 rue de l'Abbaye           Reims        None
# 1                                 Luisenstr. 48         Münster        None
# 2                               Rua do Paço, 67  Rio de Janeiro          RJ
# 3                            2, rue du Commerce            Lyon        None
# 4                          Boulevard Tirou, 255       Charleroi        None
# ..                                          ...             ...         ...
# 147  Carrera 22 con Ave. Carlos Soublette #8-35   San Cristóbal     Táchira
# 148                           Berliner Platz 43         München        None
# 149                      Estrada da saúde n. 58          Lisboa        None
# 150                             187 Suffolk Ln.           Boise          ID
# 151                               Smagsloget 45           Århus        None
#
#     ship_postal_code ship_country
# 0              51100       France
# 1              44087      Germany
# 2          05454-876       Brazil
# 3              69004       France
# 4             B-6000      Belgium
# ..               ...          ...
# 147             5022    Venezuela
# 148            80805      Germany
# 149             1756     Portugal
# 150            83720          USA
# 151             8200      Denmark
#
# [152 rows x 14 columns]

# %%
query("""select first_name || ' ' || last_name as nombre_completo, date_part('year', age(birth_date)) as edad, country
from employees""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#     nombre_completo  edad country
# 0     Andrew Fuller  73.0     USA
# 1   Janet Leverling  62.0     USA
# 2  Margaret Peacock  88.0     USA
# 3   Steven Buchanan  70.0      UK
# 4    Michael Suyama  62.0      UK
# 5       Robert King  65.0      UK
# 6    Laura Callahan  67.0     USA
# 7    Anne Dodsworth  59.0      UK
# 8     Nancy Davolio  76.0     USA

# %%
query("""select count(order_id) from orders where order_date >= '1997-07-15'""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#    count
# 0    479

# %%
query("""select avg(shipped_date - order_date) from orders
where shipped_date is not null""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#         avg
# 0  8.491965

# %% [markdown]
# ## 4. Reportes para preparar la temporada de Navidad
# 1. Lista todos los pedidos, saca un campo extra _is_christmas_season_ que sea True si el pedido se hizo en temporada de navidad o False si se hizo fuera de temporada
# 2. Necesitamos hacer un Sanity Check en la base de datos para comprobar que está todo en orden antes de empezar la temporada de Navidad... ¿Podrías comprobar que el número de pedidos en la tabla **orders** coincide con el número de pedidos de la tabla **order_details**?
# 3. Queremos enviar un regalo a empleados y clientes. Extrae en un mismo reporte (query) la lista de ambos, los campos que se necesitan son el nombre completo, la dirección, el codigo postal, ciudad y país
#
# Consideramos temporada de Navidad desde el 1 de Diciembre al 31 de Diciembre de cualquier año.
#
# _Funciones útiles: [CASE WHEN](https://www.w3schools.com/sql/sql_case.asp), [DATE_PART](https://www.postgresql.org/docs/8.1/functions-datetime.html), [UNION](https://www.w3schools.com/sql/sql_union.asp), [DISTINCT](https://www.w3schools.com/sql/sql_distinct.asp)_

# %%
query("""
select
    order_id,
    order_date,
    case
        when date_part('month', order_date) = 12
             and date_part('day', order_date) between 1 and 31
        then true
        else false
    end as is_christmas_season
from orders
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#      order_id  order_date  is_christmas_season
# 0       10248  1996-07-04                False
# 1       10249  1996-07-05                False
# 2       10250  1996-07-08                False
# 3       10251  1996-07-08                False
# 4       10252  1996-07-09                False
# ..        ...         ...                  ...
# 825     11073  1998-05-05                False
# 826     11074  1998-05-06                False
# 827     11075  1998-05-06                False
# 828     11076  1998-05-06                False
# 829     11077  1998-05-06                False
#
# [830 rows x 3 columns]

# %%
query("""
select
    (select count(order_id) from orders) as orders_count,
    (select count(distinct order_id) from order_details) as order_details_count
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#    orders_count  order_details_count
# 0           830                  830

# %%
query("""
select
    company_name as nombre_completo,
    address,
    postal_code,
    city,
    country
from customers

union

select
    first_name || ' ' || last_name as nombre_completo,
    address,
    postal_code,
    city,
    country
from employees
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#                    nombre_completo                 address postal_code  \
# 0                  Janet Leverling      722 Moss Bay Blvd.       98033
# 1               Ricardo Adocicados     Av. Copacabana, 267   02389-890
# 2                    B's Beverages       Fauntleroy Circus     EC2 5NT
# 3   Furia Bacalhau e Frutos do Mar  Jardim das rosas n. 32        1675
# 4                  Around the Horn         120 Hanover Sq.     WA1 1DP
# ..                             ...                     ...         ...
# 95            Spécialités du monde       25, rue Lauriston       75016
# 96                La maison d'Asie   1 rue Alsace-Lorraine       31000
# 97                  Folk och fä HB            Åkergatan 24    S-844 67
# 98               Chop-suey Chinese            Hauptstr. 29        3012
# 99                    Vaffeljernet           Smagsloget 45        8200
#
#               city      country
# 0         Kirkland          USA
# 1   Rio de Janeiro       Brazil
# 2           London           UK
# 3           Lisboa     Portugal
# 4           London           UK
# ..             ...          ...
# 95           Paris       France
# 96        Toulouse       France
# 97          Bräcke       Sweden
# 98            Bern  Switzerland
# 99           Århus      Denmark
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 5. Investigar el retraso de algunos Orders 1/2
# Podemos considerar un Order como retrasado cuando la fecha de envío es superior a la fecha requerida.
# 1. ¿Cuántos Orders hay con retraso?
# 2. Sacar una lista de todos los orders con el nombre de los shippers (distribuidores)
# 3. Sacar una lista única de los distribuidores que tienen retrasos
# 4. Sacar una lista única de todos los distribuidores, marcando los que han tenido retraso alguna vez y los que no, sólo para pedidos hechos durante el año 1998
# 5. Listar la lista de pedidos con sus empleados asociados que se enviarón después de la fecha requerida (required_date)
#
# _Funciones útiles: [JOINS](https://www.w3schools.com/sql/sql_join.asp), [UNION](https://www.w3schools.com/sql/sql_union.asp), [DISTINCT](https://www.w3schools.com/sql/sql_distinct.asp), [WITH](https://www.postgresql.org/docs/current/queries-with.html#QUERIES-WITH-SELECT)_

# %%
query("""
select count(*) as orders_retrasados
from orders
where shipped_date > required_date
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#    orders_retrasados
# 0                 37

# %%
query("""
select
    o.order_id,
    s.company_name as shipper_name,
    o.shipped_date,
    o.required_date
from orders o
join shippers s on o.ship_via = s.shipper_id
where o.shipped_date > o.required_date
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#     order_id      shipper_name shipped_date required_date
# 0      10264  Federal Shipping   1996-08-23    1996-08-21
# 1      10271    United Package   1996-08-30    1996-08-29
# 2      10280    Speedy Express   1996-09-12    1996-09-11
# 3      10302    United Package   1996-10-09    1996-10-08
# 4      10309    Speedy Express   1996-10-23    1996-10-17
# 5      10320  Federal Shipping   1996-10-18    1996-10-17
# 6      10380  Federal Shipping   1997-01-16    1997-01-09
# 7      10423  Federal Shipping   1997-02-24    1997-02-06
# 8      10427    United Package   1997-03-03    1997-02-24
# 9      10433  Federal Shipping   1997-03-04    1997-03-03
# 10     10451  Federal Shipping   1997-03-12    1997-03-05
# 11     10483    United Package   1997-04-25    1997-04-21
# 12     10515    Speedy Express   1997-05-23    1997-05-07
# 13     10523    United Package   1997-05-30    1997-05-29
# 14     10545    United Package   1997-06-26    1997-06-19
# 15     10578  Federal Shipping   1997-07-25    1997-07-22
# 16     10593    United Package   1997-08-13    1997-08-06
# 17     10596    Speedy Express   1997-08-12    1997-08-08
# 18     10660    Speedy Express   1997-10-15    1997-10-06
# 19     10663    United Package   1997-10-03    1997-09-24
# 20     10687    United Package   1997-10-30    1997-10-28
# 21     10705    United Package   1997-11-18    1997-11-12
# 22     10709  Federal Shipping   1997-11-20    1997-11-14
# 23     10726    Speedy Express   1997-12-05    1997-11-17
# 24     10727    Speedy Express   1997-12-05    1997-12-01
# 25     10749    United Package   1997-12-19    1997-12-18
# 26     10777    United Package   1998-01-21    1997-12-29
# 27     10779    United Package   1998-01-14    1998-01-13
# 28     10807    Speedy Express   1998-01-30    1998-01-28
# 29     10816    United Package   1998-02-04    1998-02-03
# 30     10827    United Package   1998-02-06    1998-01-26
# 31     10828    Speedy Express   1998-02-04    1998-01-27
# 32     10847  Federal Shipping   1998-02-10    1998-02-05
# 33     10924    United Package   1998-04-08    1998-04-01
# 34     10927    Speedy Express   1998-04-08    1998-04-02
# 35     10960    Speedy Express   1998-04-08    1998-04-02
# 36     10970    Speedy Express   1998-04-24    1998-04-07

# %%
query("""
select distinct
    s.company_name as shipper_name
from orders o
join shippers s on o.ship_via = s.shipper_id
where o.shipped_date > o.required_date
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#        shipper_name
# 0    United Package
# 1    Speedy Express
# 2  Federal Shipping

# %%
query("""
select
    s.company_name as shipper_name,
    case
        when count(case when o.shipped_date > o.required_date then 1 end) > 0
        then 'tuvo retrasos'
        else 'sin retrasos'
    end as estado_retraso
from orders o
join shippers s on o.ship_via = s.shipper_id
where date_part('year', o.order_date) = 1998
group by s.company_name
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#        shipper_name estado_retraso
# 0  Federal Shipping  Tuvo retrasos
# 1    Speedy Express  Tuvo retrasos
# 2    United Package  Tuvo retrasos

# %%
query("""
select
    o.order_id,
    o.shipped_date,
    o.required_date,
    e.first_name || ' ' || e.last_name as empleado
from orders o
join employees e on o.employee_id = e.employee_id
where o.shipped_date > o.required_date
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#     order_id shipped_date required_date          empleado
# 0      10264   1996-08-23    1996-08-21    Michael Suyama
# 1      10271   1996-08-30    1996-08-29    Michael Suyama
# 2      10280   1996-09-12    1996-09-11     Andrew Fuller
# 3      10302   1996-10-09    1996-10-08  Margaret Peacock
# 4      10309   1996-10-23    1996-10-17   Janet Leverling
# 5      10320   1996-10-18    1996-10-17   Steven Buchanan
# 6      10380   1997-01-16    1997-01-09    Laura Callahan
# 7      10423   1997-02-24    1997-02-06    Michael Suyama
# 8      10427   1997-03-03    1997-02-24  Margaret Peacock
# 9      10433   1997-03-04    1997-03-03   Janet Leverling
# 10     10451   1997-03-12    1997-03-05  Margaret Peacock
# 11     10483   1997-04-25    1997-04-21       Robert King
# 12     10515   1997-05-23    1997-05-07     Andrew Fuller
# 13     10523   1997-05-30    1997-05-29       Robert King
# 14     10545   1997-06-26    1997-06-19    Laura Callahan
# 15     10578   1997-07-25    1997-07-22  Margaret Peacock
# 16     10593   1997-08-13    1997-08-06       Robert King
# 17     10596   1997-08-12    1997-08-08    Laura Callahan
# 18     10660   1997-10-15    1997-10-06    Laura Callahan
# 19     10663   1997-10-03    1997-09-24     Andrew Fuller
# 20     10687   1997-10-30    1997-10-28    Anne Dodsworth
# 21     10705   1997-11-18    1997-11-12    Anne Dodsworth
# 22     10709   1997-11-20    1997-11-14     Nancy Davolio
# 23     10726   1997-12-05    1997-11-17  Margaret Peacock
# 24     10727   1997-12-05    1997-12-01     Andrew Fuller
# 25     10749   1997-12-19    1997-12-18  Margaret Peacock
# 26     10777   1998-01-21    1997-12-29       Robert King
# 27     10779   1998-01-14    1998-01-13   Janet Leverling
# 28     10807   1998-01-30    1998-01-28  Margaret Peacock
# 29     10816   1998-02-04    1998-02-03  Margaret Peacock
# 30     10827   1998-02-06    1998-01-26     Nancy Davolio
# 31     10828   1998-02-04    1998-01-27    Anne Dodsworth
# 32     10847   1998-02-10    1998-02-05  Margaret Peacock
# 33     10924   1998-04-08    1998-04-01   Janet Leverling
# 34     10927   1998-04-08    1998-04-02  Margaret Peacock
# 35     10960   1998-04-08    1998-04-02   Janet Leverling
# 36     10970   1998-04-24    1998-04-07    Anne Dodsworth

# %% [markdown]
# ## 6. Investigar el retraso de algunos orders 2/2
# 1. ¿Cuántos pedidos retrasados hay por año?
# 2. ¿Cuántos pedidos retrasados tiene cada distribuidor? ¿Y por año?
# 3. Top 2 empleados con más pedidos retrasados
# 4. Top 2 meses con más pedidos retrasados (mes y año)
# 5. ¿Hay alguna relación entre el número de productos de un pedido y el retraso?
#
# _Funciones útiles: [GROUP BY](https://www.w3schools.com/sql/sql_groupby.asp), [JOINS](https://www.w3schools.com/sql/sql_join.asp)_

# %%
# ¿Cuántos pedidos retrasados hay por año?
query(""" select
    date_part('year', required_date) as año,
    count(*) as pedidos_retrasados
from orders
where shipped_date > required_date
group by date_part('year', required_date)
order by año
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#       año  pedidos_retrasados
# 0  1996.0                   6
# 1  1997.0                  21
# 2  1998.0                  10

# %%
# ¿Cuántos pedidos retrasados tiene cada distribuidor y por año?
query("""
select
    s.company_name as distribuidor,
    date_part('year', o.required_date) as año,
    count(*) as pedidos_retrasados
from orders o
join shippers s on o.ship_via = s.shipper_id
where o.shipped_date > o.required_date
group by s.company_name, date_part('year', o.required_date)
order by distribuidor, año
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#        distribuidor     año  pedidos_retrasados
# 0  Federal Shipping  1996.0                   2
# 1  Federal Shipping  1997.0                   6
# 2  Federal Shipping  1998.0                   1
# 3    Speedy Express  1996.0                   2
# 4    Speedy Express  1997.0                   5
# 5    Speedy Express  1998.0                   5
# 6    United Package  1996.0                   2
# 7    United Package  1997.0                  10
# 8    United Package  1998.0                   4

# %%
# Top 2 empleados con más pedidos retrasados
query("""
select
    e.first_name || ' ' || e.last_name as empleado,
    count(*) as total_retrasos
from orders o
join employees e on o.employee_id = e.employee_id
where o.shipped_date > o.required_date
group by empleado
order by total_retrasos desc
limit 2
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#            empleado  total_retrasos
# 0  Margaret Peacock              10
# 1   Janet Leverling               5

# %%
# Top 2 meses con más pedidos retrasados (mes y año)
query("""
select
    date_part('year', required_date) as año,
    date_part('month', required_date) as mes,
    count(*) as total_retrasos
from orders
where shipped_date > required_date
group by año, mes
order by total_retrasos desc
limit 2
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#       año  mes  total_retrasos
# 0  1998.0  4.0               4
# 1  1998.0  1.0               4

# %%
# ¿Hay relación entre el número de productos y el retraso?
query("""
select
    o.order_id,
    count(od.product_id) as cantidad_productos,
    case
        when o.shipped_date > o.required_date then true
        else false
    end as retrasado
from orders o
join order_details od on o.order_id = od.order_id
group by o.order_id, retrasado
order by cantidad_productos desc
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#      order_id  cantidad_productos  retrasado
# 0       11077                  25      False
# 1       10847                   6       True
# 2       10657                   6      False
# 3       10979                   6      False
# 4       10893                   5      False
# ..        ...                 ...        ...
# 825     10608                   1      False
# 826     10942                   1      False
# 827     10878                   1      False
# 828     10771                   1      False
# 829     11044                   1      False
#
# [830 rows x 3 columns]

# %% [markdown]
# ### 7. Estudio de los empleados
# 1. ¿Cuál es la distribución de empleados en los distintos territorios?
# 2. ¿Cuál es la distribución de los empleados en estos rangos de edad 30-40, 40-60, 60+?
# 3. Reporte que muestre el número de empleados y clientes que hay en cada ciudad que tenga empleados (es decir, no estamos interesados en las ciudades sin empleados)
#
# _Funciones útiles: [CASE WHEN](https://www.w3schools.com/sql/sql_case.asp), [DATE_PART](https://www.postgresql.org/docs/8.1/functions-datetime.html), [UNION](https://www.w3schools.com/sql/sql_union.asp)_

# %%
query("""select
    t.territory_description as territorio,
    count(e.employee_id) as cantidad_empleados
from employees e
join employee_territories et on e.employee_id = et.employee_id
join territories t on et.territory_id = t.territory_id
group by t.territory_description
order by cantidad_empleados desc""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#           territorio  cantidad_empleados
# 0           New York                   2
# 1         Santa Cruz                   1
# 2           Westboro                   1
# 3       Philadelphia                   1
# 4            Phoenix                   1
# 5      San Francisco                   1
# 6          Roseville                   1
# 7         Southfield                   1
# 8          Rockville                   1
# 9         Morristown                   1
# 10           Orlando                   1
# 11        Portsmouth                   1
# 12         Georgetow                   1
# 13       Santa Clara                   1
# 14           Chicago                   1
# 15              Cary                   1
# 16          Fairport                   1
# 17  Colorado Springs                   1
# 18            Denver                   1
# 19   Hoffman Estates                   1
# 20            Edison                   1
# 21         Beachwood                   1
# 22           Bedford                   1
# 23          Campbell                   1
# 24        Menlo Park                   1
# 25        Providence                   1
# 26       Minneapolis                   1
# 27           Findlay                   1
# 28        Louisville                   1
# 29          Savannah                   1
# 30             Tampa                   1
# 31           Seattle                   1
# 32            Racine                   1
# 33           Atlanta                   1
# 34           Redmond                   1
# 35          Mellvile                   1
# 36            Hollis                   1
# 37            Boston                   1
# 38         Braintree                   1
# 39  Bloomfield Hills                   1
# 40        Scottsdale                   1
# 41          Bellevue                   1
# 42              Troy                   1
# 43      Santa Monica                   1
# 44        Greensboro                   1
# 45            Wilton                   1
# 46            Neward                   1
# 47         Cambridge                   1

# %%
query("""select
    case
        when date_part('year', age(birth_date)) between 30 and 40 then '30-40'
        when date_part('year', age(birth_date)) between 41 and 60 then '40-60'
        when date_part('year', age(birth_date)) > 60 then '60+'
        else 'Menor de 30'
    end as rango_edad,
    count(*) as cantidad_empleados
from employees
group by rango_edad
order by rango_edad""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#   rango_edad  cantidad_empleados
# 0      40-60                   1
# 1        60+                   8

# %%
query("""with empleados_por_ciudad as (
    select city, count(*) as num_empleados
    from employees
    group by city
),
clientes_por_ciudad as (
    select city, count(*) as num_clientes
    from customers
    group by city
)
select
    e.city,
    e.num_empleados,
    coalesce(c.num_clientes, 0) as num_clientes
from empleados_por_ciudad e
left join clientes_por_ciudad c on e.city = c.city
order by e.num_empleados desc""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#        city  num_empleados  num_clientes
# 0    London              4             6
# 1   Seattle              2             1
# 2  Kirkland              1             1
# 3    Tacoma              1             0
# 4   Redmond              1             0

# %% [markdown]
# ## 8. Eficiencia de la operación según la relación empleado - cliente - pedido
# 1. Teniendo en cuenta los pedidos gestionados por cada empleado, ¿cuántos clientes gestiona de media cada empleado?
# 2. ¿Cuál es el empleado (nombre) que ha gestionado más clientes? ¿Y más pedidos?
# 3. Saca una lista con empleados (nombre) que incluya sólo aquellos que han gestionado más de 100 pedidos

# %%
# ¿Cuántos clientes gestiona de media cada empleado?
query("""select round(avg(num_clientes),2) as media_clientes_por_empleado
from (
    select e.employee_id, count(distinct o.customer_id) as num_clientes
    from orders o
    join employees e on o.employee_id = e.employee_id
    group by e.employee_id
) sub""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#    media_clientes_por_empleado
# 0                        51.56

# %%
# ¿Cuál es el empleado (nombre) que ha gestionado más clientes? ¿Y más pedidos?
query("""select e.first_name || ' ' || e.last_name as empleado,
count(distinct o.customer_id) as clientes_gestionados
from orders o
join employees e on o.employee_id = e.employee_id
group by e.employee_id, e.first_name, e.last_name
order by clientes_gestionados desc
limit 1""")

query("""select e.first_name || ' ' || e.last_name as empleado,
count(o.order_id) as pedidos_gestionados
from orders o
join employees e on o.employee_id = e.employee_id
group by e.employee_id, e.first_name, e.last_name
order by pedidos_gestionados desc
limit 1""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#            empleado  pedidos_gestionados
# 0  Margaret Peacock                  156

# %%
# Lista de empleados (nombre) que han gestionado más de 100 pedidos
query("""select e.first_name || ' ' || e.last_name as empleado,
count(o.order_id) as total_pedidos
from orders o
join employees e on o.employee_id = e.employee_id
group by e.employee_id, e.first_name, e.last_name
having count(o.order_id) > 100
order by total_pedidos desc""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#            empleado  total_pedidos
# 0  Margaret Peacock            156
# 1   Janet Leverling            127
# 2     Nancy Davolio            123
# 3    Laura Callahan            104

# %% [markdown]
# ## 9. Reporte que incluya un resumen de las siguientes métricas (todo en la misma tabla)
# 1. Número total de pedidos
# 2. Número total de pedidos retrasados
# 3. % de pedidos retrasados
# 4. Media de pedidos gestionados por empleado
#
# Todas esas métricas deberán de aparecer por año y més (el ejemplo de abajo es orientativo, los números no son reales):
#
# | año     | mes | total_pedidos | pedidos_retrasados | % pedidos retrasados | pedidos_por_empleado
# |----------|----------|----------|----------|----------|----------|
# | 1996    |  enero  | 134 | 43 |0.03 |19 |
# | 1996    | febrero   | 532 | 63 |0.02 |103 |
# | 1996    | marzo   | 149 | 34 |0.18 |25 |

# %%
query("""
select
    date_part('year', order_date) as año,
    to_char(order_date, 'month') as mes,
    count(order_id) as total_pedidos,
    count(case when shipped_date > required_date then 1 end) as pedidos_retrasados,
    round(
        100.0 * count(case when shipped_date > required_date then 1 end) / count(*),
        2
    ) as porcentaje_retrasados,
    round(
        avg(num_pedidos_por_empleado),
        2
    ) as pedidos_por_empleado
from orders,
(
    select employee_id, count(order_id) as num_pedidos_por_empleado
    from orders
    group by employee_id
) sub
group by año, mes, date_part('month', order_date)
order by año, date_part('month', order_date)
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#        año        mes  total_pedidos  pedidos_retrasados  \
# 0   1996.0  july                 198                   9
# 1   1996.0  august               225                  18
# 2   1996.0  september            207                  18
# 3   1996.0  october              234                   9
# 4   1996.0  november             225                   0
# 5   1996.0  december             279                   9
# 6   1997.0  january              297                  18
# 7   1997.0  february             261                  18
# 8   1997.0  march                270                   9
# 9   1997.0  april                279                   9
# 10  1997.0  may                  288                  18
# 11  1997.0  june                 270                   9
# 12  1997.0  july                 297                  18
# 13  1997.0  august               297                   0
# 14  1997.0  september            333                  27
# 15  1997.0  october              342                  18
# 16  1997.0  november             306                  27
# 17  1997.0  december             432                  27
# 18  1998.0  january              495                  36
# 19  1998.0  february             486                   0
# 20  1998.0  march                657                  36
# 21  1998.0  april                666                   0
# 22  1998.0  may                  126                   0
#
#     porcentaje_retrasados  pedidos_por_empleado
# 0                    4.55                 92.22
# 1                    8.00                 92.22
# 2                    8.70                 92.22
# 3                    3.85                 92.22
# 4                    0.00                 92.22
# 5                    3.23                 92.22
# 6                    6.06                 92.22
# 7                    6.90                 92.22
# 8                    3.33                 92.22
# 9                    3.23                 92.22
# 10                   6.25                 92.22
# 11                   3.33                 92.22
# 12                   6.06                 92.22
# 13                   0.00                 92.22
# 14                   8.11                 92.22
# 15                   5.26                 92.22
# 16                   8.82                 92.22
# 17                   6.25                 92.22
# 18                   7.27                 92.22
# 19                   0.00                 92.22
# 20                   5.48                 92.22
# 21                   0.00                 92.22
# 22                   0.00                 92.22

# %% [markdown]
# ## 10. Comprobaciones finales:
# 1. ¿Cuáles son las categorías que tienen los productos más caros?
# 2. ¿Cuáles son los productos (nombre) que tienen unidades en orden y cuáles son sus categorías y distribuidores?
# 3. ¿Cuál es el precio total de cada pedido?

# %%
# ¿Cuáles son las categorías que tienen los productos más caros?
query("""
select c.category_name, max(p.unit_price) as precio_maximo
from products p
join categories c on p.category_id = c.category_id
group by c.category_name
order by precio_maximo desc
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#     category_name  precio_maximo
# 0       Beverages         263.50
# 1    Meat/Poultry         123.79
# 2     Confections          81.00
# 3         Seafood          62.50
# 4  Dairy Products          55.00
# 5         Produce          53.00
# 6      Condiments          43.90
# 7  Grains/Cereals          38.00

# %%
# ¿Cuáles son los productos (nombre) que tienen unidades en orden y cuáles son sus categorías y distribuidores?
query("""
select distinct
    p.product_name,
    c.category_name,
    s.company_name as distribuidor
from products p
join categories c on p.category_id = c.category_id
join suppliers s on p.supplier_id = s.supplier_id
join order_details od on p.product_id = od.product_id
where od.quantity > 0
order by p.product_name
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#                        product_name   category_name  \
# 0                      Alice Mutton    Meat/Poultry
# 1                     Aniseed Syrup      Condiments
# 2                  Boston Crab Meat         Seafood
# 3                 Camembert Pierrot  Dairy Products
# 4                  Carnarvon Tigers         Seafood
# ..                              ...             ...
# 72  Uncle Bob's Organic Dried Pears         Produce
# 73                 Valkoinen suklaa     Confections
# 74                     Vegie-spread      Condiments
# 75        Wimmers gute Semmelknödel  Grains/Cereals
# 76                    Zaanse koeken     Confections
#
#                          distribuidor
# 0                       Pavlova, Ltd.
# 1                      Exotic Liquids
# 2         New England Seafood Cannery
# 3                        Gai pâturage
# 4                       Pavlova, Ltd.
# ..                                ...
# 72          Grandma Kelly's Homestead
# 73                          Karkki Oy
# 74                      Pavlova, Ltd.
# 75  Plutzer Lebensmittelgroßmärkte AG
# 76                Zaanse Snoepfabriek
#
# [77 rows x 3 columns]

# %%
# ¿Cuál es el precio total de cada pedido?
query("""
select
    o.order_id,
    round(sum(od.unit_price * od.quantity * (1 - od.discount))) as precio_total
from orders o
join order_details od on o.order_id = od.order_id
group by o.order_id
order by o.order_id
""")
# Out:
# /tmp/ipython-input-1710432509.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql, connection)
#      order_id  precio_total
# 0       10248         440.0
# 1       10249        1863.0
# 2       10250        1553.0
# 3       10251         654.0
# 4       10252        3598.0
# ..        ...           ...
# 825     11073         300.0
# 826     11074         232.0
# 827     11075         498.0
# 828     11076         793.0
# 829     11077        1256.0
#
# [830 rows x 2 columns]

# %% [markdown]
# ## Extra: Window Functions
# Aunque esta sección no se evaluará, se recomienda la realización por parte del alumno que quiera profundizar y mejorar su nivel de SQL.
# 1. Por cada pedido y producto de Order Details, crear una columna llamada __order_page__ indicando el número de página de cada pedido (es decir, un mismo pedido con 3 productos tendrá un producto con un order page 1, otro con un order page 2 y otro con un order page 3)
# 2. Sacar la evolución del beneficio total obtenido por los pedidos a lo largo del tiempo (beneficio acumulado)
# 3. Asignar a cada empleado un ranking numérico según el beneficio generado por la gestión de pedidos, es decir el empleado con la posicion 1 será el que haya tenido más beneficio en ventas
# 4. Reporte donde se muestre el ID del pedido, el empleado que lo gestionó, la fecha, y el acumulado de pedidos de ese empleado hasta ese momento
# 5. Crear un reporte donde se muestre la evolución del beneficio por mes y año, además queremos que cada año el acumulado sea independiente, es decir que el 1 de Enero el acumulado se reinicie a 0 (la tabla tendrá tres columnas: año, mes y beneficio)
